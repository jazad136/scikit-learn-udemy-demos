# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# What if your data doesn't look linear at all? Let's look at some more realistic-looking page speed / purchase data:

# %%
np.set_printoptions(legacy='1.25')

# %%
import seaborn as sns
import pandas as pd
sns.set()
df = pd.DataFrame({'PageSpeeds':pageSpeeds,'PurchaseAmount':purchaseAmount})

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from pylab import *
import numpy as np

np.random.seed(2)
pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = np.random.normal(50.0, 10.0, 1000) / pageSpeeds

sns.scatterplot(x=pageSpeeds, y=purchaseAmount, data=df)
plt.show()

# %% [markdown]
# numpy has a handy polyfit function we can use, to let us construct an nth-degree polynomial model of our data that minimizes squared error. Let's try it with a 4th degree polynomial:

# %%
x = np.array(pageSpeeds)
y = np.array(purchaseAmount)

p4 = np.poly1d(np.polyfit(x, y, 3))

# %% [markdown]
# We'll visualize our original scatter plot, together with a plot of our predicted values using the polynomial for page speed times ranging from 0-7 seconds:

# %%
import matplotlib.pyplot as plt

xp = np.linspace(0, 7, 100)
sns.scatterplot(x=x, y=y, data=df)
plt.plot(xp, p4(xp), c='r')
plt.show()

# %% [markdown]
# Looks pretty good! Let's measure the r-squared error:

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y, p4(x))

print(r2)
#0.7842354030823269
# Out:
# 0.7842354030823269

# %% [markdown]
# ## Activity

# %% [markdown]
# Try different polynomial orders. Can you get a better fit with higher orders? Do you start to see overfitting, even though the r-squared score looks good for this particular data set?

# %%
p4 = np.poly1d(np.polyfit(x, y, 4))
xp = np.linspace(0, 7, 100)
sns.scatterplot(x=x, y=y, data=df)
plt.plot(xp, p4(xp), c='r')
print(r2_score(y, p4(x)))
plt.show()
# 1st degree: 0.5024941304548025 (not good) 
# 2nd degree: 0.6927446350535892 (better, but misses the top) 
# 3rd degree: 0.7842354030823269 (much better but still misses the top)
# 4th degree: 0.8293766396303073 (.04 increase, a little better, even though it misses the tippy top)
# 5th degree: 0.8553884386186104 (.03 increase, 
# doesn't improve much from the 4th, lumps at the bottom)
# Out:
# 0.8293766396303073

# %%
conda install scikit-learn
# Out:
# Retrieving notices: done
# Channels:
#  - conda-forge
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\JonathanSaddler\miniforge3\envs\py3_12lsp
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     joblib-1.5.3               |     pyhd8ed1ab_0         221 KB  conda-forge
#     narwhals-2.22.1            |     pyhcf101f3_0         279 KB  conda-forge
#     scikit-learn-1.9.0         |np2py312hea30aaf_0         8.7 MB  conda-forge
#     threadpoolctl-3.6.0        |     pyhecae5ae_0          23 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         9.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   joblib             conda-forge/noarch::joblib-1.5.3-pyhd8ed1ab_0
# ...
